# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pokemon_df = pd.read_csv('Pokemon.csv',index_col = 0)

# %%
pokemon_df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemon_df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#xc = pokemon_df.columns
#print(xc)
#pokemon_df.shape
#pokemon_df.index
pokemon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 800 entries, 1 to 721
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 66.4+ KB

# %%
pokemon_df['Type 2'].fillna(value = 'NA', inplace = True)

# %%
pokemon_df.info
# Out:
# <bound method DataFrame.info of                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire      NA    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemon_df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
pokemon_df.to_csv("Pokemon_cleaned.csv")

# %%
legendry_df = pokemon_df[pokemon_df['Legendary']==True]

# %%
legendry_df.head()
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# #
# 144             Articuno       Ice    Flying    580   90      85      100
# 145               Zapdos  Electric    Flying    580   90      90       85
# 146              Moltres      Fire    Flying    580   90     100       90
# 150               Mewtwo   Psychic        NA    680  106     110       90
# 150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# 144       95      125     85           1       True
# 145      125       90    100           1       True
# 146      125       85     90           1       True
# 150      154       90    130           1       True
# 150      154      100    130           1       True

# %%
pokemon_df['Type 1']
# Out:
# #
# 1        Grass
# 2        Grass
# 3        Grass
# 3        Grass
# 4         Fire
#         ...
# 719       Rock
# 719       Rock
# 720    Psychic
# 720    Psychic
# 721       Fire
# Name: Type 1, Length: 800, dtype: object

# %%
pokemon_df['Type 1'].unique()
#pokemon_df['Type 1'].value_counts()
pokemon_df['Type 1'].value_counts().sort_values()
# Out:
# Flying        4
# Fairy        17
# Ice          24
# Steel        27
# Fighting     27
# Poison       28
# Dark         31
# Dragon       32
# Ghost        32
# Ground       32
# Rock         44
# Electric     44
# Fire         52
# Psychic      57
# Bug          69
# Grass        70
# Normal       98
# Water       112
# Name: Type 1, dtype: int64

# %%
#pokemon_df['Type 1'].value_counts().sort_values(ascending=False).plot(kind = 'barh')
#pokemon_df['Type 1'].value_counts().plot(kind='barh')
ax = sns.countplot(pokemon_df['Type 1'])
g = ax.set_xticklabels(ax.get_xticklabels(),rotation =65)
# Out:
# c:\users\tushar mani\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
ax = sns.countplot(pokemon_df[pokemon_df['Type 2']!='NA']['Type 2'])
g = ax.set_xticklabels(ax.get_xticklabels(),rotation =65)
# Out:
# c:\users\tushar mani\appdata\local\programs\python\python37-32\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.displot(data=pokemon_df['Speed'], kde=True) #kernel density estimate

# %%
for c in pokemon_df.columns:
    sns.displot(data=pokemon_df[c],kde=True)
# Out:
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <string>:6: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
list(set(pokemon_df.dtypes.tolist()))
df_num = pokemon_df.select_dtypes(include = ['float64','int64'])
df_num
#df_num=df_num.drop(['Generation'],axis=1)
# Out:
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# #
# 1      318  45      49       49       65       65     45           1
# 2      405  60      62       63       80       80     60           1
# 3      525  80      82       83      100      100     80           1
# 3      625  80     100      123      122      120     80           1
# 4      309  39      52       43       60       50     65           1
# ..     ...  ..     ...      ...      ...      ...    ...         ...
# 719    600  50     100      150      100      150     50           6
# 719    700  50     160      110      160      110    110           6
# 720    600  80     110       60      150      130     70           6
# 720    680  80     160       60      170      130     80           6
# 721    600  80     110      120      130       90     70           6
#
# [800 rows x 8 columns]

# %%
df_num
# Out:
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# #
# 1      318  45      49       49       65       65     45
# 2      405  60      62       63       80       80     60
# 3      525  80      82       83      100      100     80
# 3      625  80     100      123      122      120     80
# 4      309  39      52       43       60       50     65
# ..     ...  ..     ...      ...      ...      ...    ...
# 719    600  50     100      150      100      150     50
# 719    700  50     160      110      160      110    110
# 720    600  80     110       60      150      130     70
# 720    680  80     160       60      170      130     80
# 721    600  80     110      120      130       90     70
#
# [800 rows x 7 columns]

# %%
df_num.index
# Out:
# Int64Index([  1,   2,   3,   3,   4,   5,   6,   6,   6,   7,
#             ...
#             714, 715, 716, 717, 718, 719, 719, 720, 720, 721],
#            dtype='int64', name='#', length=800)

# %%
df_num = df_num[~df_num.index.duplicated(keep='first')]
sns.pairplot(df_num, diag_kind="kde")

# %%
pokemon_df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire      NA    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
plt.subplots(figsize = (20,5))
plt.title('Attack by Type 2')
sns.boxplot(x= "Type 2", y = "Attack",data = pokemon_df)
# Out:
# <AxesSubplot:title={'center':'Attack by Type 2'}, xlabel='Type 2', ylabel='Attack'>

# %%
plt.subplots(figsize = (80,40))
plt.title('Attack by Defense')
sns.boxplot(x= "Defense", y = "Attack",data = pokemon_df)
# Out:
# <AxesSubplot:title={'center':'Attack by Defense'}, xlabel='Defense', ylabel='Attack'>

# %%
type_grounded =pokemon_df[pokemon_df['Type 2']!='NA'].groupby(['Type 1','Type 2']).size()
print(type_grounded)
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Length: 136, dtype: int64

# %%
normal_data = np.random.randn(10,12)
ax=sns.heatmap(normal_data)

# %%
df_num.corr()
# Out:
#                Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# Total       1.000000  0.642628  0.704247  0.605786  0.723143  0.707223
# HP          0.642628  1.000000  0.425839  0.234177  0.362636  0.382569
# Attack      0.704247  0.425839  1.000000  0.434022  0.339699  0.208322
# Defense     0.605786  0.234177  0.434022  1.000000  0.202188  0.479991
# Sp. Atk     0.723143  0.362636  0.339699  0.202188  1.000000  0.493038
# Sp. Def     0.707223  0.382569  0.208322  0.479991  0.493038  1.000000
# Speed       0.548890  0.170031  0.332172 -0.006849  0.439548  0.236499
# Generation  0.092868  0.071545  0.100852  0.061406  0.076737  0.047802
#
#                Speed  Generation
# Total       0.548890    0.092868
# HP          0.170031    0.071545
# Attack      0.332172    0.100852
# Defense    -0.006849    0.061406
# Sp. Atk     0.439548    0.076737
# Sp. Def     0.236499    0.047802
# Speed       1.000000    0.003920
# Generation  0.003920    1.000000

# %%
sns.heatmap(df_num.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df_num.corr(),annot =True, fmt =' .2f')
# Out:
# <AxesSubplot:>

# %%
type_grounded.unstack()
# Out:
# Type 2    Bug  Dark  Dragon  Electric  Fairy  Fighting  Fire  Flying  Ghost  \
# Type 1
# Bug       NaN   NaN     NaN       2.0    NaN       2.0   2.0    14.0    1.0
# Dark      NaN   NaN     3.0       NaN    NaN       2.0   3.0     5.0    2.0
# Dragon    NaN   NaN     NaN       1.0    1.0       NaN   1.0     6.0    NaN
# Electric  NaN   NaN     1.0       NaN    1.0       NaN   1.0     5.0    1.0
# Fairy     NaN   NaN     NaN       NaN    NaN       NaN   NaN     2.0    NaN
# Fighting  NaN   1.0     NaN       NaN    NaN       NaN   NaN     1.0    NaN
# Fire      NaN   NaN     1.0       NaN    NaN       7.0   NaN     6.0    NaN
# Flying    NaN   NaN     2.0       NaN    NaN       NaN   NaN     NaN    NaN
# Ghost     NaN   1.0     2.0       NaN    NaN       NaN   3.0     2.0    NaN
# Grass     NaN   3.0     1.0       NaN    2.0       3.0   NaN     5.0    NaN
# Ground    NaN   3.0     2.0       1.0    NaN       NaN   1.0     4.0    2.0
# ...

# %%
#sns.heatmap(type_grounded)

# %%
pokemon_gen = legendry_df.groupby('Generation')['Name'].count().reset_index(name='counts')
pokemon_gen
# Out:
#    Generation  counts
# 0           1       6
# 1           2       5
# 2           3      18
# 3           4      13
# 4           5      15
# 5           6       8

# %%
sns.lineplot(data=pokemon_gen['counts'])
# Out:
# <AxesSubplot:ylabel='counts'>

# %%
sns.regplot(x="Generation",y="counts",
            data= pokemon_gen,
            marker=">",
            color='b',
            x_estimator=np.mean,
            logx=True)
# Out:
# <AxesSubplot:xlabel='Generation', ylabel='counts'>
